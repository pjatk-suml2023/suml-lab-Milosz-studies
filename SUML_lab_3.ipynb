# %% [markdown]
# <a href="https://colab.research.google.com/github/pjatk-suml2023/suml-lab-Milosz-studies/blob/main/SUML_lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import bibliotek

# %%
import os
import pandas as pd

# %%
from platform import python_version
python_version()
# Out:
# '3.10.12'

# %% [markdown]
# # Przygotowanie danych do analizy

# %%
original_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datasets/DSP_4.csv', sep=';')

# %%
original_df
# Out:
#     objawy  wiek  choroby  wzrost  leki
# 0        1   NaN        0   170.0     2
# 1        1  65.0        0     NaN     3
# 2        1  55.0        0   182.0     4
# 3        1  44.0        0   187.0     3
# 4        1  77.0        0   165.0     2
# 5        1  64.0        0   164.0     1
# 6        1  54.0        1   178.0     4
# 7        1   NaN        1   190.0     3
# 8        3  76.0        1   200.0     2
# 9        3  54.0        0   198.0     1
# 10       3  56.0        0   187.0     2
# 11       3  68.0        0   167.0     3
# 12       3   NaN        1   168.0     2
# 13       3  55.0        1   189.0     1
# 14       3  44.0        1   177.0     2
# 15       3  43.0        1   166.0     3
# 16       2  32.0        1   188.0     4
# 17       2  23.0        1   198.0     3
# 18       2  42.0        0   176.0     2
# 19       2   NaN        0   167.0     1
# 20       2  11.0        0   159.0     2
# 21       2  21.0        0   198.0     3
# ...

# %%
original_df.isnull().any()
# Out:
# objawy     False
# wiek        True
# choroby    False
# wzrost      True
# leki       False
# dtype: bool

# %%
mean_wiek = original_df['wiek'].mean()
mean_wzrost = original_df['wzrost'].mean()
(mean_wiek, mean_wzrost)
# Out:
# (44.163636363636364, 183.34545454545454)

# %%
df = original_df.fillna(original_df.mean())

# %%
df
# Out:
#     objawy       wiek  choroby      wzrost  leki
# 0        1  44.163636        0  170.000000     2
# 1        1  65.000000        0  183.345455     3
# 2        1  55.000000        0  182.000000     4
# 3        1  44.000000        0  187.000000     3
# 4        1  77.000000        0  165.000000     2
# 5        1  64.000000        0  164.000000     1
# 6        1  54.000000        1  178.000000     4
# 7        1  44.163636        1  190.000000     3
# 8        3  76.000000        1  200.000000     2
# 9        3  54.000000        0  198.000000     1
# 10       3  56.000000        0  187.000000     2
# 11       3  68.000000        0  167.000000     3
# 12       3  44.163636        1  168.000000     2
# 13       3  55.000000        1  189.000000     1
# 14       3  44.000000        1  177.000000     2
# 15       3  43.000000        1  166.000000     3
# 16       2  32.000000        1  188.000000     4
# 17       2  23.000000        1  198.000000     3
# ...

# %% [markdown]
# # Podstawowe statystyki opisowe

# %%
round(df.describe(), 2)
# Out:
#        objawy  ...   leki
# count   60.00  ...  60.00
# mean     2.53  ...   2.50
# std      1.29  ...   1.03
# min      1.00  ...   1.00
# 25%      2.00  ...   2.00
# 50%      2.00  ...   2.50
# 75%      4.00  ...   3.00
# max      5.00  ...   4.00
#
# [8 rows x 5 columns]

# %%
df['wiek'].groupby(df['objawy']).describe()
# Out:
#         count  ...     max
# objawy         ...
# 1        14.0  ...  77.000
# 2        22.0  ...  44.164
# 3         8.0  ...  76.000
# 4        10.0  ...  76.000
# 5         6.0  ...  42.000
#
# [5 rows x 8 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from scipy.stats import pearsonr

# %%
df.corr()
# Out:
#          objawy  ...   leki
# objawy    1.000  ... -0.051
# wiek     -0.102  ... -0.218
# choroby   0.111  ...  0.046
# wzrost    0.161  ...  0.011
# leki     -0.051  ...  1.000
#
# [5 rows x 5 columns]

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True)
plt.figure(figsize=(10, 5))
heatmap.set_title('Analiza korelacji', fontdict={'fontsize': 14}, pad=12)
# Out:
# Text(0.5, 1.0, 'Analiza korelacji')

# %% [markdown]
# # Zadanie 1

# %%
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 2)
pd.set_option('display.max_info_columns', 1000)
pd.set_option('display.precision', 3)

# %%
display(df)
# Out:
#     objawy  ...  leki
# 0        1  ...     2
# 1        1  ...     3
# 2        1  ...     4
# 3        1  ...     3
# 4        1  ...     2
# ..     ...  ...   ...
# 55       5  ...     1
# 56       5  ...     2
# 57       5  ...     3
# 58       5  ...     4
# 59       5  ...     3
#
# [60 rows x 5 columns]

# %%
pd.reset_option('all')
# Out:
# <ipython-input-60-056908e7e3ef>:1: FutureWarning: column_space is deprecated and will be removed in a future version. Use df.to_string(col_space=...) instead.
#   pd.reset_option('all')
# <ipython-input-60-056908e7e3ef>:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead.
#   pd.reset_option('all')
# <ipython-input-60-056908e7e3ef>:1: FutureWarning:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
#
#   pd.reset_option('all')

# %% [markdown]
# # Zadanie 2

# %% [markdown]
# **Wypełnianie medianą**

# %%
df_3 = original_df.fillna(original_df.median())

# %%
{
    'wiek_mediana': original_df['wiek'].median(),
    'wzrost_mediana': original_df['wzrost'].median()
}
# Out:
# {'wiek_mediana': 43.0, 'wzrost_mediana': 187.0}

# %%
df_3
# Out:
#     objawy  wiek  choroby  wzrost  leki
# 0        1  43.0        0   170.0     2
# 1        1  65.0        0   187.0     3
# 2        1  55.0        0   182.0     4
# 3        1  44.0        0   187.0     3
# 4        1  77.0        0   165.0     2
# 5        1  64.0        0   164.0     1
# 6        1  54.0        1   178.0     4
# 7        1  43.0        1   190.0     3
# 8        3  76.0        1   200.0     2
# 9        3  54.0        0   198.0     1
# 10       3  56.0        0   187.0     2
# 11       3  68.0        0   167.0     3
# 12       3  43.0        1   168.0     2
# 13       3  55.0        1   189.0     1
# 14       3  44.0        1   177.0     2
# 15       3  43.0        1   166.0     3
# 16       2  32.0        1   188.0     4
# 17       2  23.0        1   198.0     3
# 18       2  42.0        0   176.0     2
# 19       2  43.0        0   167.0     1
# 20       2  11.0        0   159.0     2
# 21       2  21.0        0   198.0     3
# ...

# %% [markdown]
# **Wypełnianie zerem**

# %%
df_4 = original_df.fillna(0)

# %%
df_4

# %% [markdown]
# # Zadanie 3

# %%
df_zad3 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datasets/DSP_5.csv', sep=';')
df_zad3

# %%
df_zad3.isnull().any()
# Out:
# model    False
# mpg      False
# cyl      False
# disp     False
# hp        True
# drat     False
# wt        True
# qsec     False
# vs       False
# am       False
# gear     False
# carb     False
# dtype: bool

# %%
df_zad3.fillna(df_zad3.mean(), inplace=True)
df_zad3
# Out:
# <ipython-input-77-bde045680c33>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_zad3.fillna(df_zad3.mean(), inplace=True)
#                   model   mpg  cyl   disp          hp  drat      wt   qsec  \
# 0             Mazda RX4  21.0    6  160.0  110.000000  3.90  2.6200  16.46
# 1         Mazda RX4 Wag  21.0    6  160.0  110.000000  3.90  2.8750  17.02
# 2            Datsun 710  22.8    4  108.0   93.000000  3.85  2.3200  18.61
# 3        Hornet 4 Drive  21.4    6  258.0  110.000000  3.08  3.2150  19.44
# 4     Hornet Sportabout  18.7    8  360.0  175.000000  3.15  3.2024  17.02
# 5               Valiant  18.1    6  225.0  105.000000  2.76  3.4600  20.22
# 6            Duster 360  14.3    8  360.0  245.000000  3.21  3.5700  15.84
# ...

# %%
df_zad3['hp'].describe()
# Out:
# count     32.000000
# mean     143.516129
# std       66.174194
# min       52.000000
# 25%       96.500000
# 50%      123.000000
# 75%      180.000000
# max      335.000000
# Name: hp, dtype: float64

# %%
heatmap = sns.heatmap(df_zad3.corr(), vmin=-1, vmax=1, annot=True)
plt.figure(figsize=(10, 5))
heatmap.set_title('Analiza korelacji', fontdict={'fontsize': 14}, pad=12)
# Out:
# <ipython-input-80-4bf03d52220b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(df_zad3.corr(), vmin=-1, vmax=1, annot=True)
# Text(0.5, 1.0, 'Analiza korelacji')

# %% [markdown]
# W oczy rzuca się w oczy korelacja pomiędzy ilością cylindrów silnika, pojemnością skokową, ilością koni i zmienną wt z ilością mil przejechanych na galonie paliwa. Generalnie dane są ze sobą silnie skorelowane

# %% [markdown]
# # Zadanie 4

# %%
df_zad4 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datasets/DSP_8.csv')
df_zad4
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
f'Ilość kolumn: {df_zad4.columns.size}; ich nazwy {list(df_zad4.columns)}'
# Out:
# "Ilość kolumn: 12; ich nazwy ['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS', 'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope', 'HeartDisease']"

# %%
len(df_zad4.index)
# Out:
# 918

# %%
df_zad3.isnull().any()
# Out:
# model    False
# mpg      False
# cyl      False
# disp     False
# hp       False
# drat     False
# wt       False
# qsec     False
# vs       False
# am       False
# gear     False
# carb     False
# dtype: bool

# %%
df_zad4.groupby('Sex')['Age'].agg(['mean', 'std'])
# Out:
#           mean       std
# Sex
# F    52.492228  9.517593
# M    53.782069  9.397864

# %%
temp = df_zad4.groupby('Sex')['Age'].agg('count')
f'Procent mężczyzn {round(temp.M / temp.sum() * 100, 2)}% : Procent kobiet {round(temp.F / temp.sum() * 100, 2)}%'
# Out:
# 'Procent mężczyzn 78.98% : Procent kobiet 21.02%'

# %%
len(df_zad4[(df_zad4['Sex'] == 'F') & (df_zad4['Age'] >= 45) & (df_zad4['Age'] <= 50)].index)
# Out:
# 36

# %%
heatmap = sns.heatmap(df_zad4[df_zad4['RestingECG'] == 'Normal'].corr(), vmin=-1, vmax=1, annot=True)
plt.figure(figsize=(10, 5))
heatmap.set_title('Analiza korelacji', fontdict={'fontsize': 14}, pad=12)
# Out:
# <ipython-input-167-97222005f06c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(df_zad4[df_zad4['RestingECG'] == 'Normal'].corr(), vmin=-1, vmax=1, annot=True)
# Text(0.5, 1.0, 'Analiza korelacji')
